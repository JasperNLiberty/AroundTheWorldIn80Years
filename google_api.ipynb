# %%
from apiclient.discovery import build

service = build("customsearch", "v1",
               developerKey="AIzaSyDHprXaJe8U1CpF7kYH6IWUktAViHhiWnc")

res = service.cse().list(
    q='tokyo',
    cx='004441307141111453178:v-kf4bu7lsy',
    searchType='image',
    num=3,
    imgType='photo',
    fileType='png',
    safe= 'off'
).execute()

if not 'items' in res:
    print 'No result !!\nres is: {}'.format(res)
else:
    for item in res['items']:
        print('{}:\n\t{}'.format(item['title'], item['link']))
# Out:
# No result !!
# ...

# %%
from apiclient.discovery import build

service = build("customsearch", "v1",
               developerKey="AIzaSyDHprXaJe8U1CpF7kYH6IWUktAViHhiWnc")

res = service.cse().list(
    q='tokyo',
    cx='004441307141111453178:v-kf4bu7lsy',
    imgType='photo',
).execute()

if not 'items' in res:
    print 'No result !!\nres is: {}'.format(res)
else:
    for item in res['items']:
        print('{}:\n\t{}'.format(item['title'], item['link']))
# Out:
# Tokyo - Wikipedia:
# 	https://en.wikipedia.org/wiki/Tokyo
# Tokyo - City Guide:
# 	http://www.japan-guide.com/e/e2164.html
# Tokyo - Lonely Planet:
# 	https://www.lonelyplanet.com/japan/tokyo
# Tokyo Metropolitan Government:
# 	http://www.metro.tokyo.jp/ENGLISH/index.htm
# Tokyo travel guide - Wikitravel:
# 	http://wikitravel.org/en/Tokyo
# HOME / Official Tokyo Travel Guide GO TOKYO:
# 	https://www.gotokyo.org/en/
# The University of Tokyo:
# 	http://www.u-tokyo.ac.jp/index_e.html
# Home | The Tokyo Organising Committee of the Olympic and ...:
# 	https://tokyo2020.jp/
# Tokyo! (2008) - IMDb:
# 	http://www.imdb.com/title/tt0976060/
# Tokyo 2016: Best of Tokyo, Japan Tourism - TripAdvisor:
# 	https://www.tripadvisor.com/Tourism-g298184-Tokyo_Tokyo_Prefecture_Kanto-Vacations.html

# %%
from apiclient.discovery import build

service = build("customsearch", "v1",
               developerKey="AIzaSyDHprXaJe8U1CpF7kYH6IWUktAViHhiWnc")

res = service.cse().list(
    q='Bruges',
    cx='004441307141111453178:v-kf4bu7lsy',
    imgType='photo',
).execute()

image_url = res['items'][0]['pagemap']['cse_image'][0]['src']
# Out:
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7c/Rozenhoedkaai_Brugge.jpg/250px-Rozenhoedkaai_Brugge.jpg

# %%
response = requests.get(image_url)
image_name = 'Bruges' + str(seq)
with open('./Images/Bruges', 'w') as f:
    f.write(response.content)

# %%
save_images('Bruges', 5)

# %%
from apiclient.discovery import build

def save_images(search_term, num_images):
    for seq in range(num_images):
        service = build("customsearch", "v1",
                       developerKey="AIzaSyDHprXaJe8U1CpF7kYH6IWUktAViHhiWnc")
        res = service.cse().list(
            q=search_term,
            cx='004441307141111453178:v-kf4bu7lsy',
            num=num_images,
            imgType='photo',
        ).execute()

        image_url = res['items'][seq]['pagemap']['cse_image'][0]['src']

        response = requests.get(image_url)
        image_name = search_term + str(seq)
        with open('./Images/'+image_name, 'w') as f:
            f.write(response.content)

# %%
import requests

# %%
response = requests.get(image_url)

# %%
with open('Bruges', 'w') as f:
    f.write(response.content)

# %%
with open('Bruges', 'r') as f:
    loaded_image = f.read()

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.image as mpimg

# %%
img=mpimg.imread('Bruges')

# %%
# %matplotlib inline
plt.imshow(img)

# %%
from pymongo import MongoClient

# %%
# connect to mongodb
client = MongoClient()
db = client.get_database("attractions")

# %%
# initialize collection
db.get_collection('result_images')
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'attractions'), u'result_images')

# %%
response.close()

# %%
txt1 = response.content

# %%
txt1
# Out:
# '\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xfe\x00NFile source: http://commons.wikimedia.org/wiki/File:Rozenhoedkaai_Brugge.jpg\xff\xe2\x1cmICC_PROFILE\x00\x01\x01\x00\x00\x1c]Lino\x02\x10\x00\x00mntrRGB XYZ \x07\xce\x00\x02\x00\t\x00\x06\x001\x00\x00acspMSFT\x00\x00\x00\x00IEC sRGB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-HP  \x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x11cprt\x00\x00\x01P\x00\x00\x003desc\x00\x00\x01\x83\x00\x00\x00lwtpt\x00\x00\x01\xef\x00\x00\x00\x14bkpt\x00\x00\x02\x03\x00\x00\x00\x14rXYZ\x00\x00\x02\x17\x00\x00\x00\x14gXYZ\x00\x00\x02+\x00\x00\x00\x14bXYZ\x00\x00\x02?\x00\x00\x00\x14dmnd\x00\x00\x02S\x00\x00\x00pdmdd\x00\x00\x02\xc3\x00\x00\x00\x88vued\x00\x00\x03K\x00\x00\x00\x86view\x00\x00\x03\xd1\x00\x00\x00$lumi\x00\x00\x03\xf5\x00\x00\x00
# ...

# %%
json.loads(txt1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-05c3864a409f> in <module>()
# ----> 1 json.loads(txt1)
#
# //anaconda/lib/python2.7/json/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337             parse_int is None and parse_float is None and
#     338             parse_constant is None and object_pairs_hook is None and not kw):
# --> 339         return _default_decoder.decode(s)
#     340     if cls is None:
#     341         cls = JSONDecoder
#
# //anaconda/lib/python2.7/json/decoder.pyc in decode(self, s, _w)
#     362
#     363         """
# --> 364         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     365         end = _w(s, end).end()
#     366         if end != len(s):
#
# //anaconda/lib/python2.7/json/decoder.pyc in raw_decode(self, s, idx)
# ...

# %%
test = response.raw

# %%
type(test)
# Out:
# requests.packages.urllib3.response.HTTPResponse

# %%
im1 = str(response.content.encode('utf-8'))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-102-9af701b90e4f> in <module>()
# ----> 1 im1 = str(response.content.encode('utf-8'))
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xff in position 0: ordinal not in range(128)

# %%
im1
# Out:
# '\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xfe\x00NFile source: http://commons.wikimedia.org/wiki/File:Rozenhoedkaai_Brugge.jpg\xff\xe2\x1cmICC_PROFILE\x00\x01\x01\x00\x00\x1c]Lino\x02\x10\x00\x00mntrRGB XYZ \x07\xce\x00\x02\x00\t\x00\x06\x001\x00\x00acspMSFT\x00\x00\x00\x00IEC sRGB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-HP  \x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x11cprt\x00\x00\x01P\x00\x00\x003desc\x00\x00\x01\x83\x00\x00\x00lwtpt\x00\x00\x01\xef\x00\x00\x00\x14bkpt\x00\x00\x02\x03\x00\x00\x00\x14rXYZ\x00\x00\x02\x17\x00\x00\x00\x14gXYZ\x00\x00\x02+\x00\x00\x00\x14bXYZ\x00\x00\x02?\x00\x00\x00\x14dmnd\x00\x00\x02S\x00\x00\x00pdmdd\x00\x00\x02\xc3\x00\x00\x00\x88vued\x00\x00\x03K\x00\x00\x00\x86view\x00\x00\x03\xd1\x00\x00\x00$lumi\x00\x00\x03\xf5\x00\x00\x00
# ...

# %%
image = {'location': 'Bruges', 'details':response.content.encode('utf-8')}
db.result_images.insert_one(image)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-101-893e828f5bae> in <module>()
# ----> 1 image = {'location': 'Bruges', 'details':response.content.encode('utf-8')}
#       2 db.result_images.insert_one(image)
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xff in position 0: ordinal not in range(128)
