# %%
from features import wiki_extract
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-95a460d02c86> in <module>()
# ----> 1 from features import wiki_extract
#
# ImportError: cannot import name wiki_extract

# %%
ws.wiki_extract('github')
# Out:
# 'From other capitalisation: This is a redirect from a title with another method of capitalisation. It leads to the title in accordance with the Wikipedia naming conventions for capitalisation, or it leads to a title that is associated in some way with the conventional capitalisation of this redirect title. This may help writing, searching and international language issues. If this redirect is an incorrect capitalisation, then {{R from miscapitalisation}} should be used instead, and pages that use this link should be updated to link directly to the target. Miscapitisations can be tagged in any namespace. Use this rcat to tag only mainspace redirects; when other capitalisations are in other namespaces, use {{R from modification}} instead.  From a misspelling: This is a redirect from a misspelling or typographical error. The correct form is given by the target of the redirect. This redirect is made available to aid searches. Pages that use this link should be updated to link directly to the target without the use of a piped link that hides the correct details. This template tags redirects with a subcategory of the Redirects from incorrect names category, so template {{R from incorrect name}} should not be used with this template.'

# %%
import pandas as pd
from pymongo import MongoClient
import requests
from bs4 import BeautifulSoup

# %%
client = MongoClient()

# %%
db = client.get_database("anything")

# %%
resp = requests.get("http://www.hillmanwonders.com/top_1000/")

# %%
soup = BeautifulSoup(resp.content, "lxml")

# %%
trs = soup.find("div", id="EdColumn").find("table").find_all("tr")

# %%
for tr in trs:
    tds = tr.find_all("td")
    country_td, names_td = tds[0], tds[1]
    data = {
            "country": country_td.get_text(),
            "name": names_td.get_text().strip().split("\n")
        }
    db.new_col.insert_one(data)

# %%
pd.DataFrame(data)
# Out:
#                                       country  \
# 0                                 Afghanistan
# 1                                     Algeria
# 2                                     America
# 3                              American Samoa
# 4                                   Argentina
# 5                                     Armenia
# 6                                   Australia
# 7                                     Austria
# 8                                  Azerbaijan
# 9                                     Bahamas
# 10                                   Barbados
# 11                                    Belgium
# 12                                     Belize
# 13                                      Benin
# 14                                    Bermuda
# 15                                     Bhutan
# 16                                    Bolivia
# 17                                   Botswana
# 18                                     Brazil
# 19                     British Virgin Islands
# 20                                   Bulgaria
# 21                                   Cambodia
# 22                                   Cameroon
# 23                                     Canada
# 24                             Cayman Islands
# 25                            Channel Islands
# 26                                      Chile
# 27                                      China
# 28                           Christmas Island
# 29                                   Colombia
# ..                                        ...
# 131                                     Sudan
# 132                                    Sweden
# 133                               Switzerland
# 134                                     Syria
# 135                                    Taiwan
# 136                                  Tanzania
# 137                                  Thailand
# 138                                     Tonga
# 139                       Trinidad and Tobago
# 140                                   Tunisia
# 141                                    Turkey
# 142                              Turkmenistan
# 143                                    Uganda
# 144                                   Ukraine
# 145                               UAE - Dubai
# 146                            UAE- Abu Dhabi
# 147                         US Virgin Islands
# 148                                Uzbekistan
# 149                                   Vanuatu
# 150                              Vatican City
# 151                                 Venezuela
# 152                                   Vietnam
# 153                                     Wales
# 154                             Western Samoa
# 155                                     Yemen
# 156                                    Zambia
# 157                                  Zimbabwe
# 158                              \nAntarctica
# 159  \nMedals shared\nby 3 or more\ncountries
# 160                Covered in\nmy other lists
#
#                                                   name
# 0    [Jam Minaret, Kabul Old City, Khyber Pass  [wi...
# 1    [Al Qal'a of Beni Hammad, Algiers Kasbah, Djem...
# 2    [Alaska Cruise, Alcatraz Island, American Muse...
# 3                                    [Ofu and Olosega]
# 4    [Christ of the Andes  [with Chile], Glacier Na...
# 5                          [Ashtarak Ancient Fortress]
# 6    [Ayers Rock  [Uluru], Bungle Bungle, Great Bar...
# 7    [Belvedere Palace, Danube Cruise  [Austria to ...
# 8    [Baku Old City, Gobustan Rock Drawings, Palace...
# 9                                    [Paradise Island]
# 10                                        [West Coast]
# 11   [Ardennes, Bruges, Ghent, Grand Place, Meuse V...
# 12   [Barrier Reef Reserve, Blue Hole, Caracol, Xun...
# 13        [Abomey Royal Palaces, Ganvie Stilt Village]
# 14                             [Bermuda Sea/Landscape]
# 15   [Bhutan Mountain Treks, Punakha Dzong, Taktsan...
# 16   [Lake Titicaca   [with Peru], Salar de Uyuni, ...
# 17   [Chobe National Park, Moremi Wildlife Reserve,...
# 18   [Amazon Rain Forest   [with Peru], Brasilia, C...
# 19                                          [The Bath]
# 20        [Ivanovo Rock-Hewn Churches, Rila Monastery]
# 21   [Angkor Thom, Angkor Wat, Phnom Bakheng, Silve...
# 22                                [Waza National Park]
# 23   [Banff National Park, Baffin Island, Bay of Fu...
# 24                                     [Stingray City]
# 25                                   [Channel Islands]
# 26   [Christ of the Andes    [with Argentina], East...
# 27   [Baishui Terrace, Bund River Front, Chengde Mo...
# 28                                [Red Crab Migration]
# 29   [Cartagena Old Town, San Agustin Archaeologica...
# ..                                                 ...
# 131  [Khartoum Old Town, Pyramids & Temples Gebel B...
# 132  [Drottningholm Castle, Kalmar Castle, Lapland ...
# 133  [Bern Old City, Chillon Chateau, Fribourg Old ...
# 134  [Aleppo Citadel, Apamea, Bosra Amphitheatre, C...
# 135  [Kenting National Park, National Palace Museum...
# 136  [Arusha National Park, Dar Es Salaam Village M...
# 137  [Ayutthaya Temples, Bangkok Floating Markets, ...
# 138                                           [Vava'u]
# 139                                [Trinidad Carnival]
# 140  [Carthage, Dougga Ancient City, Great Mosque o...
# 141  [Antalya, Basilica Cistern, Blue Mosque, Bodru...
# 142                [Door to Hell fire pit, Merv Ruins]
# 143  [Mountain Gorilla Habitats, Murchison & Karuma...
# 144                     [Kiev Old City, Lvov Old City]
# 145  [Burj Al Arab, Burj Khalifa, Palm Islands, Ski...
# 146  [Aldar spherical tower, Emirates Palace, Sheik...
# 147                                        [Trunk Bay]
# 148  [Bukhara Old Town, Registan Square in Samarkan...
# 149                                          [Vanuatu]
# 150  [Sistine Chapel, St Peter's Basilica, St Peter...
# 151  [Angel Falls, Canaima Table Mountain Cliffs, G...
# 152  [Cu Chi Tunnels, Halong Bay, Hoi An Old Town, ...
# 153  [Caernarfon Castle, Cardiff Castle, Conwy & it...
# 154                                            [Upolu]
# 155     [Barakesh, Sana'a Old City, Wadi Dhar, Shibam]
# 156  [South Luangwa National Park, Victoria Falls  ...
# 157  [Great Zimbabwe Ruins, Hwange National Park, M...
# 158  [Antarctica, Deception Island, Dry Valleys, Ic...
# 159  [Congo Rain Forest, Kalahari Desert, Lake Vict...
# 160                                                 []
#
# [161 rows x 2 columns]

# %%
tables = pd.read_html("http://www.hillmanwonders.com/top_1000/")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-1168055c237e> in <module>()
# ----> 1 tables = pd.read_html("http://www.hillmanwonders.com/top_1000/")
#
# //anaconda/lib/python2.7/site-packages/pandas/io/html.pyc in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding)
#     872     _validate_header_arg(header)
#     873     return _parse(flavor, io, match, header, index_col, skiprows,
# --> 874                   parse_dates, tupleize_cols, thousands, attrs, encoding)
#
# //anaconda/lib/python2.7/site-packages/pandas/io/html.pyc in _parse(flavor, io, match, header, index_col, skiprows, parse_dates, tupleize_cols, thousands, attrs, encoding)
#     737
#     738     ret = []
# --> 739     for table in tables:
#     740         try:
#     741             ret.append(_data_to_frame(data=table,
#
# //anaconda/lib/python2.7/site-packages/pandas/io/html.pyc in <genexpr>((table,))
#     195     def parse_tables(self):
#     196         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
# --> 197         return (self._build_table(table) for table in tables)
#     198
#     199     def _parse_raw_data(self, rows):
#
# //anaconda/lib/python2.7/site-packages/pandas/io/html.pyc in _build_table(self, table)
#     347
#     348     def _build_table(self, table):
# --> 349         header = self._parse_raw_thead(table)
#     350         body = self._parse_raw_tbody(table)
#     351         footer = self._parse_raw_tfoot(table)
#
# //anaconda/lib/python2.7/site-packages/pandas/io/html.pyc in _parse_raw_thead(self, table)
#     353
#     354     def _parse_raw_thead(self, table):
# --> 355         thead = self._parse_thead(table)
#     356         res = []
#     357         if thead:
#
# //anaconda/lib/python2.7/site-packages/pandas/io/html.pyc in _parse_thead(self, table)
#     411
#     412     def _parse_thead(self, table):
# --> 413         return table.find_all('thead')
#     414
#     415     def _parse_tbody(self, table):
#
# //anaconda/lib/python2.7/site-packages/bs4/element.pyc in find_all(self, name, attrs, recursive, text, limit, **kwargs)
#    1257         if not recursive:
#    1258             generator = self.children
# -> 1259         return self._find_all(name, attrs, text, limit, generator, **kwargs)
#    1260     findAll = find_all       # BS3
#    1261     findChildren = find_all  # BS2
#
# //anaconda/lib/python2.7/site-packages/bs4/element.pyc in _find_all(self, name, attrs, text, limit, generator, **kwargs)
#     527                           if isinstance(element, Tag)
#     528                             and element.name == name)
# --> 529                 return ResultSet(strainer, result)
#     530         results = ResultSet(strainer)
#     531         while True:
#
# //anaconda/lib/python2.7/site-packages/bs4/element.pyc in __init__(self, source, result)
#    1722     that created it."""
#    1723     def __init__(self, source, result=()):
# -> 1724         super(ResultSet, self).__init__(result)
#    1725         self.source = source
#
# //anaconda/lib/python2.7/site-packages/bs4/element.pyc in <genexpr>((element,))
#     524             elif isinstance(name, basestring):
#     525                 # Optimization to find all tags with a given name.
# --> 526                 result = (element for element in generator
#     527                           if isinstance(element, Tag)
#     528                             and element.name == name)
#
# //anaconda/lib/python2.7/site-packages/bs4/element.pyc in descendants(self)
#    1275         while current is not stopNode:
#    1276             yield current
# -> 1277             current = current.next_element
#    1278
#    1279     # CSS selector code
#
# AttributeError: 'NoneType' object has no attribute 'next_element'
